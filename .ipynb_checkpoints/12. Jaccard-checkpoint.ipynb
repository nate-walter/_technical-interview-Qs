# %% [markdown]
# Calculate the Jaccard similarity between two sets: the size of intersection divided by the size of union.

# %% [markdown]
# <div>
# <img src="attachment:Screen%20Shot%202021-10-23%20at%2012.43.37%20PM.png" length="200" width="300" align="left"/>
# </div>

# %% [raw]
# jaccard({'a', 'b', 'c'}, {'a', 'd'}) = 1/4

# %%
a = {'a', 'b', 'c', 'd', 'e'}
b = {'c', 'h', 'z', 'y'}

# %%
def jaccard(a, b):
    return len(a & b) / len(a | b)
