# %% [markdown]
# We have a list with identifiers of form “id-SITE”. Calculate how many ids we have per site.
#
# ![counter_1.png](attachment:counter_1.png)

# %%
def counter(lst):
    ans = {}
    for i in lst:
        site = i[-2:]
        ans[site] = ans.get(site, 0) + 1
    return ans
